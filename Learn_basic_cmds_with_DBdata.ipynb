# %%
df=spark.read.table("samples.bakehouse.sales_franchises")

# %%
df.show()

# %%
display(df)

# %%
df.write.saveAsTable("test.test_schema.test_table")

# %%
df.count()

# %%
df2 = df.limit(10)

# %%
df2.count()

# %%
df2.printSchema()

# %%
df2.write.format("json").save("/Volumes/test/test_schema/myvolume/test_schema_out/jsonfile")
